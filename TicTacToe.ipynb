# %%
def tictactoe():
    from IPython.display import clear_output
    empty = []    
    tictac = {7 :' ' , 8:' ', 9:' ',
              4 :' ' , 5:' ', 6:' ',
              1 :' ' , 2:' ', 3:' '}
    def board(board):
        print (board[7]+'|'+board[8]+'|'+board[9])
        print('-+-+-')
        print (board[4]+'|'+board[5]+'|'+board[6])
        print('-+-+-')
        print (board[1]+'|'+board[2]+'|'+board[3])
    board(tictac)
    x = input('First turn. You are X. Where do you want to place it ?. It is according to the numpad')
    while x not in ['1','2','3','4','5','6','7','8','9']:
        x = input('First turn. You are X. Where do you want to place it ?')
    x = int(x) 
    tictac[x] = 'X'
    board(tictac)
    empty.append(x)
    
    y = input('Second turn. You are O. Where do you want to place it ?. It is according to the numpad')
    while y not in ['1','2','3','4','5','6','7','8','9'] or  int(y) == x:
        y=input('Second turn. You are O. Where do you want to place it ?')
    y = int(y) 
    clear_output()
    tictac[y] = 'O'
    board(tictac)
    empty.append(y)
    
    z = input('Where do you want to place it ?.')
    while z not in ['1','2','3','4','5','6','7','8','9'] or int(z) == x or int(z) == y:
        z = input(' Where do you want to place it ?')
    z = int(z) 
    clear_output()
    tictac[z] = 'X'
    board(tictac)
    empty.append(z)
    
    a = input('Where do you want to place it ?.')
    while a not in ['1','2','3','4','5','6','7','8','9'] or int(a) == z or int(a) == x or int(a) == y:
        a = input(' Where do you want to place it ?')
    a = int(a) 
    tictac[a] = 'O'
    clear_output()
    board(tictac)
    empty.append(a)
    
    b = input('Where do you want to place it ?.')
    while b not in ['1','2','3','4','5','6','7','8','9'] or int(b) == a or int(b) == y or int(b) == z:
        b = input(' Where do you want to place it ?')
    b = int(b) 
    tictac[b] = 'X'
    clear_output()
    board(tictac)
    empty.append(b)
    if tictac[7] =='X' and tictac[5] == 'X' and tictac[3] == 'X':
        print ("X wins")
        return
    elif tictac[7] == 'X' and tictac[4] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    elif tictac[7] == 'X' and tictac[8] == 'X' and tictac[9] == 'X' :
        print ("X Wins")
        return
    elif tictac[8] == 'X' and tictac[5] == 'X' and tictac[2] == 'X' :
        print ("X Wins")
        return
    elif tictac[9] == 'X' and tictac[5] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    elif tictac[9] == 'X' and tictac[6] == 'X' and tictac[3] == 'X' :
        print ("X Wins")
        return
    elif tictac[4] == 'X' and tictac[5] == 'X' and tictac[6] == 'X' :
        print ("X Wins")
        return
    elif tictac[2] == 'X' and tictac[3] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    
    
    c = input('Where do you want to place it ?.')
    while c not in ['1','2','3','4','5','6','7','8','9'] or int(c) == b or int(c) == a or int(c) == z or int(c) == y or int(c) == x:
        c = input(' Where do you want to place it ?')
    c = int(c) 
    tictac[c] = 'O'
    clear_output()
    board(tictac)
    empty.append(c)
    if tictac[7] =='O' and tictac[5] == 'O' and tictac[3] == 'O':
        print ("O wins")
        return
    elif tictac[7] == 'O' and tictac[4] == 'O' and tictac[1] == 'O' :
        print ("O Wins")
        return
    elif tictac[7] == 'O' and tictac[8] == 'O' and tictac[9] == 'O' :
        print ("O Wins")
        return
    elif tictac[8] == 'O' and tictac[5] == 'O' and tictac[2] == 'O' :
        print ("O Wins")
        return
    elif tictac[9] == 'O' and tictac[5] == 'O' and tictac[1] == 'O' :
        print ("O Wins")
        return
    elif tictac[9] == 'O' and tictac[6] == 'O' and tictac[3] == 'O' :
        print ("O Wins")
        return
    elif tictac[4] == 'O' and tictac[5] == 'O' and tictac[6] == 'O' :
        print ("O Wins")
        return
    elif tictac[2] == 'O' and tictac[3] == 'O' and tictac[1] == 'O' :
        print ("O Wins")
        return

    
    d = input('Where do you want to place it ?.')
    while d not in ['1','2','3','4','5','6','7','8','9'] or int(d) == c or int(d) == b or int(d) == a or int(d) == z or int(d) == x or int(d) == y:
        d = input(' Where do you want to place it ?')
    d = int(d) 
    tictac[d] = 'X'
    clear_output()
    board(tictac)
    empty.append(d)
    if tictac[7] =='X' and tictac[5] == 'X' and tictac[3] == 'X':
        print ("X wins")
        return
    elif tictac[7] == 'X' and tictac[4] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    elif tictac[7] == 'X' and tictac[8] == 'X' and tictac[9] == 'X' :
        print ("X Wins")
        return
    elif tictac[8] == 'X' and tictac[5] == 'X' and tictac[2] == 'X' :
        print ("X Wins")
        return
    elif tictac[9] == 'X' and tictac[5] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    elif tictac[9] == 'X' and tictac[6] == 'X' and tictac[3] == 'X' :
        print ("X Wins")
        return
    elif tictac[4] == 'X' and tictac[5] == 'X' and tictac[6] == 'X' :
        print ("X Wins")
        return
    elif tictac[2] == 'X' and tictac[3] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    
    e = input('Where do you want to place it ?.')
    while e not in ['1','2','3','4','5','6','7','8','9'] or int(e) == d or int(e) == c or int(e) == b or int(e) == a or int(e) == x or int(e) == y or int(e) == z:
        e = input(' Where do you want to place it ?')
    e = int(e) 
    tictac[e] = 'O'
    clear_output()
    board(tictac)
    empty.append(e)
    if tictac[7] =='O' and tictac[5] == 'O' and tictac[3] == 'O':
        print ("O wins")
        return
    elif tictac[7] == 'O' and tictac[4] == 'O' and tictac[1] == 'O' :
        print ("O Wins")
        return
    elif tictac[7] == 'O' and tictac[8] == 'O' and tictac[9] == 'O' :
        print ("O Wins")
        return
    elif tictac[8] == 'O' and tictac[5] == 'O' and tictac[2] == 'O' :
        print ("O Wins")
        return
    elif tictac[9] == 'O' and tictac[5] == 'O' and tictac[1] == 'O' :
        print ("O Wins")
        return
    elif tictac[9] == 'O' and tictac[6] == 'O' and tictac[3] == 'O' :
        print ("O Wins")
        return
    elif tictac[4] == 'O' and tictac[5] == 'O' and tictac[6] == 'O' :
        print ("O Wins")
        return
    elif tictac[2] == 'O' and tictac[3] == 'O' and tictac[1] == 'O' :
        print ("O Wins")
        return

    
    f = input('Where do you want to place it ?.')
    while f not in ['1','2','3','4','5','6','7','8','9'] or int(f) == e or int(f) == d or int(f) == c or int(f) == b or int(f) == a or int(f) == z or int(f) == y or int(f) == x:
        f = input(' Where do you want to place it ?')
    f = int(f) 
    tictac[f] = 'X'
    clear_output()
    board(tictac)
    empty.append(f)
    if tictac[7] =='X' and tictac[5] == 'X' and tictac[3] == 'X':
        print ("X wins")
        return
    elif tictac[7] == 'X' and tictac[4] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    elif tictac[7] == 'X' and tictac[8] == 'X' and tictac[9] == 'X' :
        print ("X Wins")
        return
    elif tictac[8] == 'X' and tictac[5] == 'X' and tictac[2] == 'X' :
        print ("X Wins")
        return
    elif tictac[9] == 'X' and tictac[5] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    elif tictac[9] == 'X' and tictac[6] == 'X' and tictac[3] == 'X' :
        print ("X Wins")
        return
    elif tictac[4] == 'X' and tictac[5] == 'X' and tictac[6] == 'X' :
        print ("X Wins")
        return
    elif tictac[2] == 'X' and tictac[3] == 'X' and tictac[1] == 'X' :
        print ("X Wins")
        return
    else:
        print('It is a draw')
    ask = input("Do u want to play again ? Yes or No :")
    if ask == 'Yes':
        tictactoe()
    else:
        return

# %%
tictactoe()
# Out:
# X|X|X
# -+-+-
# O|O|
# -+-+-
#  | |
# X Wins
